# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Boston = pd.read_csv('../../ALL_CSV_FILES/Boston.csv')

# %%
Boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv  col  col_add
# 0       15.3   4.98  24.0  0.0      0.0
# 1       17.8   9.14  21.6  0.0      0.0
# ...

# %%
Boston = Boston.drop(['col'], axis='columns')

# %%
Boston.shape
# Out:
# (506, 13)

# %%
Boston['col2'] = np.zeros(Boston.shape[0])
Boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv  col1  col2
# 0   4.98  24.0   0.0   0.0
# 1   9.14  21.6   0.0   0.0
# 2   4.03  34.7   0.0   0.0
# 3   2.94  33.4   0.0   0.0
# 4   5.33  36.2   0.0   0.0

# %%
Boston.shape
# Out:
# (506, 15)

# %%
fig, axes = plt.subplots(5, 3, figsize=(12, 12))

boston_col = np.array(Boston.columns).reshape(5, 3)
ynumber = np.random.choice([0,1,2])

for i in range(5):
    for j in range(3):
        y_col = np.random.choice([0,1,2])
        axes[i,j].scatter(Boston[boston_col[i][j]], Boston[boston_col[0][y_col]], marker='o');
        axes[i,j].set_title(f"{boston_col[i][j]} vs. {boston_col[0][y_col]}")
        axes[i,j].set_xlabel(boston_col[i][j])
        axes[i,j].set_ylabel(boston_col[0][y_col])

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.scatter(Boston['zn'], Boston['crim'])
ax.set_title('ZN vs. Crime Rate')
ax.set_xlabel('ZN')
ax.set_ylabel('Crime Rate')
# Out:
# Text(0, 0.5, 'Crime Rate')

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.scatter(Boston['indus'], Boston['crim'], color='green')
ax.set_title('Industry vs. Crime Rate')
ax.set_xlabel('Industry')
ax.set_ylabel('Crime Rate');

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.scatter(Boston['rm'], Boston['crim'], color='green')
ax.set_title('Rooms vs. Crime Rate')
ax.set_xlabel('Rooms')
ax.set_ylabel('Crime Rate');

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.scatter(Boston['age'], Boston['crim'], color='green')
ax.set_title('Age vs. Crime Rate')
ax.set_xlabel('Age')
ax.set_ylabel('Crime Rate');

# %%
rv_idx = Boston['chas'] == 1
len(Boston[rv_idx])
# Out:
# 35

# %%
Boston['ptratio'].describe()
# Out:
# count    506.000000
# mean      18.455534
# std        2.164946
# min       12.600000
# 25%       17.400000
# 50%       19.050000
# 75%       20.200000
# max       22.000000
# Name: ptratio, dtype: float64

# %%
median = np.median(Boston['ptratio'])
median
# Out:
# 19.05

# %%
idx_boston = Boston['rm'] >= 7
Boston[idx_boston]
# Out:
#          crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 2     0.02729   0.0   7.07     0  0.4690  7.185  61.1  4.9671    2  242
# 4     0.06905   0.0   2.18     0  0.4580  7.147  54.2  6.0622    3  222
# 40    0.03359  75.0   2.95     0  0.4280  7.024  15.8  5.4011    3  252
# 55    0.01311  90.0   1.22     0  0.4030  7.249  21.9  8.6966    5  226
# 64    0.01951  17.5   1.38     0  0.4161  7.104  59.5  9.2229    3  216
# ..        ...   ...    ...   ...     ...    ...   ...     ...  ...  ...
# 364   3.47428   0.0  18.10     1  0.7180  8.780  82.9  1.9047   24  666
# 370   6.53876   0.0  18.10     1  0.6310  7.016  97.5  1.2024   24  666
# 375  19.60910   0.0  18.10     0  0.6710  7.313  97.9  1.3163   24  666
# 453   8.24809   0.0  18.10     0  0.7130  7.393  99.3  2.4527   24  666
# 482   5.73116   0.0  18.10     0  0.5320  7.061  77.0  3.4106   24  666
#
#      ptratio  lstat  medv  col1  col2
# 2       17.8   4.03  34.7   0.0   0.0
# ...

# %%
idx_boston = Boston['rm'] >= 8
len(Boston[idx_boston])
# Out:
# 13
